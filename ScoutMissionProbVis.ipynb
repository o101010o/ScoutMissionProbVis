# %% [markdown]
# ### Step #1. find a target node on the map. Index number in the range of \[1, 111\]
# ![title](fig.png)
# Type in your target index below (defualt value: 42):

# %%
target_node = 42

# %% [markdown]
# ### Step #2. control color_map variable

# %%
import matplotlib.colors as colors
col_lookup = ['grey', 'red', 'orange', 'yellow', 'greenyellow', 'lime', 'magenta']
col_boundaries = [0, 1e-16, 0.01, 0.1, 0.25, 0.5, 0.97, 1.1]

# %% [markdown]
# ### Step #3. Restart the kernel and run all

# %%
# generate image
from src.draws import generate_picture_by_index
generate_picture_by_index(root_dir="./", index_n=target_node, ext_col_lookup=col_lookup, ext_col_boundaries=col_boundaries)

# load image
from IPython.display import Image

# %%
print("self-stand v.s. others-stand")
Image("0.png")
# Out:
# self-stand v.s. others-stand

# %%
print("self-stand v.s. others-crawl")
Image("1.png")
# Out:
# self-stand v.s. others-crawl

# %%
print("self-crawl v.s. others-stand")
Image("2.png")
# Out:
# self-crawl v.s. others-stand

# %%
print("self-crawl v.s. others-crawl")
Image("3.png")
# Out:
# self-crawl v.s. others-crawl
